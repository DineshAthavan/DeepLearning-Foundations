# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/deeplearning_x/?couponCode=202508" target="_blank">A deep understanding of deep learning</a></h1>|
# |-|:-:|
# |<h2>Section:</h2>|<h1>Math, numpy, pytorch<h1>|
# |<h2>Lecture:</h2>|<h1><b>Min/max and argmin/max<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/deeplearning_x/?couponCode=202508" target="_blank">udemy.com/course/deeplearning_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
# import libraries
import numpy as np
import torch

#argmin and argmax are used to identify the location of min and max from a vector or matrix. Generally applied to output of softmax function to identify the category label of result

# %% [markdown]
# # Using numpy

# %%
# create a vector
v = np.array([ 1,40,2,-3 ])

# find and report the maximum and minimum values
minval = np.min(v)
maxval = np.max(v)

print('Min,max: %g,%g' %(minval,maxval) )


# now for the argmin/max
minidx = np.argmin(v)#Index location of minimum value
maxidx = np.argmax(v)#Index location of maximum value

print('Min,max indices: %g,%g' %(minidx,maxidx) ), print(' ')

# confirm
print(f'Min val is { v[minidx] }, max val is { v[maxidx] }')
# Out:
# Min,max: -3,40
# Min,max indices: 3,1
#
# Min val is -3, max val is 40

# %%
# repeat with matrix
M = np.array([ [0,1,10], [20,8,5] ])
print(M), print(' ')

# various minima in this matrix!
minvals1 = np.min(M)        # minimum from ENTIRE matrix
minvals2 = np.min(M,axis=0) # minimum of each column (across rows)
minvals3 = np.min(M,axis=1) # minimum of each row (across columns)

# print them out
print(minvals1)
print(minvals2)
print(minvals3)
# Out:
# [[ 0  1 10]
#  [20  8  5]]
#
# 0
# [0 1 5]
# [0 5]

# %%
# various minima in this matrix!
minidx1 = np.argmin(M)        # minimum from ENTIRE matrix - Linear index of 0
minidx2 = np.argmin(M,axis=0) # minimum of each column (across rows) - Row numbers where min is located across columns
minidx3 = np.argmin(M,axis=1) # minimum of each row (across columns) -  Col numbers where min is located across rows

# print them out
print(M), print(' ') # reminder
print(minidx1)
print(minidx2)
print(minidx3)
# Out:
# [[ 0  1 10]
#  [20  8  5]]
#
# 0
# [0 0 1]
# [0 2]

# %% [markdown]
# # Now using pytorch

# %%
# create a vector
v = torch.tensor([ 1,40,2,-3 ])

# find and report the maximum and minimum values
minval = torch.min(v)
maxval = torch.max(v)

print('Min,max: %g,%g' %(minval,maxval) )


# now for the argmin/max
minidx = torch.argmin(v)
maxidx = torch.argmax(v)

print('Min,max indices: %g,%g' %(minidx,maxidx) ), print(' ')

# confirm
print(f'Min val is { v[minidx] }, max val is { v[maxidx] }')
# Out:
# Min,max: -3,40
# Min,max indices: 3,1
#
# Min val is -3, max val is 40

# %%
# repeat with matrix
M = torch.tensor([ [0,1,10], [20,8,5] ])
print(M), print(' ')

# various minima in this matrix!
min1 = torch.min(M)        # minimum from ENTIRE matrix
min2 = torch.min(M,axis=0) # minimum of each column (across rows) - Both value and index is returned to min2 as a object.
min3 = torch.min(M,axis=1) # minimum of each row (across columns) - Both values and indexes are returned to min3 as a object.

# min function with axis parameter returns a object with value, index and also other methods like count etc.,
# Purpose of argmin is contained within the min function call itself when applied to a matrix with second input axis argument

# print them out
print(min1), print(' ')
print(min2), print(' ')
print(min2.values)
print(min2.indices)
# Out:
# tensor([[ 0,  1, 10],
#         [20,  8,  5]])
#
# tensor(0)
#
# torch.return_types.min(
# values=tensor([0, 1, 5]),
# indices=tensor([0, 0, 1]))
#
# tensor([0, 1, 5])
# tensor([0, 0, 1])
# <built-in method values of Tensor object at 0x787716406a80>
# <built-in method indices of Tensor object at 0x787716406a80>

# %%
min2.count
